# %%
from __future__ import print_function
import os
import pandas as pd
from pymongo import MongoClient

df_all=pd.read_csv('all_industriers.csv')
df_all=df_all.sort_values(by=['Code'])
path ='E:\Data'
folders=[]

files = os.listdir(path)
for name in files:
    folders.append(name)
files[0]
# Out:
# '11-1011.00'

# %%
element =files.index('19-1023.00')
element
# Out:
# 242

# %%
fixed='E:/data/'
for i in range(len(folders)):
    folders[i]=fixed+folders[i]

# %%
del df_all['Unnamed: 0']
colName=df_all.columns.tolist()
length1=len(folders)

# %%
client = MongoClient()
DB_NAME = 'O_net'
db = client[DB_NAME]
scraping = db['Occupation_Details3']

# %%
def save_To_Mongo(page):
        scraping.insert(page,check_keys= False)

# %%
folders[0]
codes=df_all['Code'].tolist()
codes[0]
list_idex=df_all.index.values
list_idex[0]
# Out:
# 939

# %%
path=''

for record in range(1080):    
    public_dic={}
    folder=[]
    folder.append(folders[record])
    if str(record) in folder[0]:
        
        for element in colName:        
            public_dic.update({element:df_all[element][list_idex[record]]})
    
        for page in folder: 
            detail_dic={}
            print(type(page))
            files = os.listdir(page)
    
            for file in files:
            
                df=pd.read_csv(page+'/'+file)
                specific_dic={}
                coulmn_name=df.columns.tolist()
                for elemnt in coulmn_name:
                    elemen_name = '_'.join(elemnt.split('_')[0:2])
                    # print(elemen_name)
                    specific_dic.update({elemen_name:df[elemnt].tolist()})
                detail_dic.update({file:specific_dic})
            public_dic.update({str(record):detail_dic})
     
        save_To_Mongo(public_dic)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# C:\Users\Mohamed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
df_all.head()
# Out:
#             Code                           Occupation  \
# 939   11-1011.00                     Chief Executives
# 940   11-1011.03        Chief Sustainability Officers
# 593   11-1021.00      General and Operations Managers
# 475   11-1031.00                          Legislators
# 1070  11-2011.00  Advertising and Promotions Managers
#
#      Projected Growth (2018-2028)  Projected Job Openings (2018-2028)  \
# 939                       Decline                             16800.0
# 940                           NaN                                 NaN
# 593           Faster than average                            230000.0
# 475                       Average                              4300.0
# 1070          Slower than average                              2700.0
#
#                                              Industries  \
# 939   Professional, Scientific, and Technical Servic...
# 940                                                 NaN
# ...

# %%
public_dic
# Out:
# {'Code': '27-3043.05',
#  'Occupation': 'Poets, Lyricists and Creative Writers',
#  'Projected Growth (2018-2028)': nan,
#  'Projected Job Openings (2018-2028)': nan,
#  'Industries': nan,
#  'URL': 'https://www.onetonline.org/link/details/27-3043.05'}

# %%
path=''
for i in names:  
    names_files=[]
    files = os.listdir(i)
    for name in files:
        names_files.append(name)
        df=pd.read_csv(i+'/'+name)
        detail_dic={}
        specific_dic={}
        coulmn_name=df.columns.tolist()
        for elemnt in coulmn_name:
            specific_dic.update({elemnt:df[elemnt]})
